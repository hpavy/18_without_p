# %% [markdown]
# ## La pression ne fonctionne pas du tout, on va comprendre pourquoi

# %%
from animate import anim 
import numpy as np
import torch 
from model import PINNs
from deepxrte.geometry import Rectangle
import pandas as pd
from utils import charge_data
import json

# %%
with open("results/9_with_15_per_axes" + "/hyper_param.json", "r") as file:
    hyper_param = json.load(file)

model = PINNs(hyper_param)
checkpoint = torch.load('results/9_with_15_per_axes/epoch150'+'/model_weights.pth', map_location=torch.device('cpu'))
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
param_adim = {
    'V':2,
    'L':0.025,
    'rho': 1.2
}

# %%
X_train, U_train, X_full, U_full, mean_std = charge_data(hyper_param, param_adim)
X_pred = torch.tensor(X_full, dtype=torch.float32)
U_pred = model(X_pred)
x_norm_pred, y_norm_pred, t_norm_pred = X_pred.detach().numpy()[:,0], X_pred.detach().numpy()[:,1], X_pred.detach().numpy()[:,2]
u_norm_pred, v_norm_pred, p_norm_pred = U_pred.detach().numpy()[:,0], U_pred.detach().numpy()[:,1], U_pred.detach().numpy()[:,2]
# Out:
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ...

# %%
torch.mean((model(torch.tensor(X_train, dtype=torch.float32))-torch.tensor(U_train))**2)
# Out:
# tensor(0.0134, dtype=torch.float64, grad_fn=<MeanBackward0>)

# %%
err_u = torch.mean((model(torch.tensor(X_train, dtype=torch.float32))[:,0]-torch.tensor(U_train)[:, 0])**2)
err_v = torch.mean((model(torch.tensor(X_train, dtype=torch.float32))[:,1]-torch.tensor(U_train)[:, 1])**2)
err_p = torch.mean((model(torch.tensor(X_train, dtype=torch.float32))[:,2]-torch.tensor(U_train)[:, 2])**2)

# %%
err_u, err_v, err_p
# Out:
# (tensor(0.0055, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.0126, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor(0.0221, dtype=torch.float64, grad_fn=<MeanBackward0>))

# %%
1/3 * (err_u + err_v + err_p)
# Out:
# tensor(0.0134, dtype=torch.float64, grad_fn=<MulBackward0>)

# %%
err_u = torch.mean((model(torch.tensor(X_full, dtype=torch.float32))[:,0]-torch.tensor(U_full)[:, 0])**2)
err_v = torch.mean((model(torch.tensor(X_full, dtype=torch.float32))[:,1]-torch.tensor(U_full)[:, 1])**2)
err_p = torch.mean((model(torch.tensor(X_full, dtype=torch.float32))[:,2]-torch.tensor(U_full)[:, 2])**2)

# %%
1/3 * (err_u + err_v + err_p)
# Out:
# tensor(0.0161, grad_fn=<MulBackward0>)

# %%
err_u, err_v, err_p
# Out:
# (tensor(0.0098, grad_fn=<MeanBackward0>),
#  tensor(0.0142, grad_fn=<MeanBackward0>),
#  tensor(0.0243, grad_fn=<MeanBackward0>))
